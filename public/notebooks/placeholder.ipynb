# %% [markdown]
# # Placeholder Project
#
# Replace this notebook with your real `.ipynb` file. Drop it in `/public/notebooks/` and update the `notebook` field in `lib/science.ts`.

# %%
import numpy as np

# Example: generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)
print(f'Generated {len(x)} data points')
# Out:
# Generated 100 data points

# %% [markdown]
# ## Methods
#
# Describe your methodology here.

# %%
# Your analysis code goes here
print('Analysis complete')
# Out:
# Analysis complete
